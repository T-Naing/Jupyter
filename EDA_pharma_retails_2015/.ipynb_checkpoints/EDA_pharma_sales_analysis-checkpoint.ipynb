# %% [markdown]
# # Exploratory Data Analysis of 2015 Pharmaceutical Retail Sales
# ## Dataset
# In this analysis, we will explore the [pharmaceutical-retails-sales-2015 dataset](https://www.kaggle.com/datasets/tigernaing/pharmaceutical-retails-sales-2015#) available on [Kaggle](https://www.kaggle.com/datasets) to manage inventory and understand sales pattern.
#
# We will focus on:
#
# * **Product Sales Distribution**: Overview of sales distribution by product.
# * **High-Frequency Sales Products**: Identification of products sold most frequently.
# * **Low-Frequency Sales Products**: Overview of low sales products.
# * **Monthly Sales Patterns**: Investigation of monthly sales patterns.
# >Run this notebook on [mybinder.org](https://mybinder.org/v2/gh/T-Naing/Jupyter/HEAD?urlpath=%2Fdoc%2Ftree%2FEDA_pharma_retails_2015%2FEDA_pharma_retails_2015.ipynb).
# >
# >https://mybinder.org/v2/gh/T-Naing/Jupyter/HEAD?urlpath=%2Fdoc%2Ftree%2FEDA_pharma_retails_2015%2FEDA_pharma_retails_2015.ipynb

# %% [markdown]
# We will install the necessary packages: pandas, matplotlib, and seaborn.

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# I've already downloaded the dataset from Kaggle, so we'll verify if 'pharma_sales_product_2015.csv' is available in the current folder.

# %%
import os

# %%
path=os.getcwd()

# %%
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  '.jupyter',
#  'EDA_pharma_retails_2015-Copy1.ipynb',
#  'EDA_pharma_retails_2015.ipynb',
#  'Monthly Sales Frequency in 2015.png',
#  'pharma_sales_product_2015 - Copy.csv',
#  'pharma_sales_product_2015.csv',
#  'requirements.txt']

# %% [markdown]
# The dataset is ready, so we'll move forward.

# %% [markdown]
# ### Import the Dataset
# We will import the **pharma_sales_product_2015.csv** file into a pandas DataFrame.

# %%
import pandas as pd

# %%
pharma_df=pd.read_csv('./pharma_sales_product_2015.csv')

# %%
pharma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22800 entries, 0 to 22799
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   InvoiceNo     22800 non-null  int64
#  1   InvoiceDate   22800 non-null  object
#  2   ProductNo     22800 non-null  int64
#  3   Quantity      22800 non-null  int64
#  4   Unit          22800 non-null  object
#  5   ProductName   22800 non-null  object
#  6   PackSize      22800 non-null  object
#  7   ChemicalName  22800 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 1.4+ MB

# %%
# pharma_df.describe()

# %%
# pharma_df.sample(5)

# %%
# pharma_df.head()

# %%
# pharma_df.tail()

# %%
# len(pharma_df.ProductNo.value_counts())

# %%
# pharma_df.ProductNo.value_counts()

# %%
pharma_df.ProductNo.nunique()
# Out:
# 873

# %% [markdown]
# ### Overview of the Dataset
# >The dataset comprises 8 columns and contains information about product sales, including InvoiceNo, InvoiceDate, Quantity, and other product details. It consists of `22,800` records.
# >
# >The dataset contains sales data from January 1, 2015, to December 31, 2015. A total of `873` products were sold during this period.

# %% [markdown]
# ## Data Preparation
# In our dataset, some items contain '?' symbols, which are originally Burmese characters. These characters were replaced with '?' during the SQL-to-CSV export process. Since the affected product names are unidentifiable, we will remove them from the dataset before proceeding with the analysis.
# ### Removing Unidentifiable Products

# %%
pharma_df[pharma_df["ProductName"].
    str.contains(r"\?", regex=True)].shape
# Out:
# (2158, 8)

# %% [markdown]
# We identified 2,158 records where the product name contains a '?'. These records will be removed from the DataFrame to ensure data accuracy before proceeding with the analysis.

# %%
pharma_df = pharma_df[~pharma_df["ProductName"].
    str.contains(r"\?", regex=True)]

# %%
pharma_df.shape
# Out:
# (20642, 8)

# %% [markdown]
# ### DateTime Conversion
# The dataset contains an 'InvoiceDate' column, currently stored as an object data type. To extract meaningful insights, we must convert it into a DateTime format.

# %%
pharma_df['InvoiceDate']=pd.DatetimeIndex(pharma_df.InvoiceDate)

# %%
pharma_df.at[22799, "InvoiceDate"].year
# Out:
# 2015

# %%
# pharma_df.head()

# %% [markdown]
# Now that the InvoiceDate column is in the correct DateTime format.
#
# Since we may examine monthly sales trends, we'll add Day, Month, and MonthName columns derived from InvoiceDate.

# %%
pharma_df['Month']=pd.DatetimeIndex(pharma_df.InvoiceDate).month
pharma_df['MonthName']=pd.DatetimeIndex(pharma_df.InvoiceDate).month_name()
pharma_df['Day']=pd.DatetimeIndex(pharma_df.InvoiceDate).day
# pharma_df['WeekDay']=pd.DatetimeIndex(pharma_df.InvoiceDate).weekday
# pharma_df['DayName']=pd.DatetimeIndex(pharma_df.InvoiceDate).day_name()

# %% [markdown]
# In our dataset, products were sold in various unit types. By utilizing pack size information (e.g., `20 tabs * 5 strips * box`), we will standardize the '*Quantity*' and '*Unit*' into **the most commonly used sales unit** and calculate the corresponding quantities (e.g., `50` `stp`) for each product before analyzing the data.
# ### Converting Product Sales to the Most Frequent Unit
# To accomplish this, we will first develop a unit conversion algorithm. Next, we will identify the most commonly used sales unit for each product and standardize all sales records accordingly.
#
# #### 1. Unit Conversion Algorithm
# The `conversion_table` function retrieves the conversion factors for each unit based on the pack size and returns the conversion table as a list.

# %%
def conversion_table(pack):
    conversions=pack.split('*')
    conversions[-1]='1 '+conversions[-1].strip()
    conversion_table=[]
    
    for conversion in conversions:
        q,u=conversion.strip().split()
        conversion_table.append((int(q),u))
    
    return conversion_table

# %% [markdown]
# The `get_index` function retrieves the index of the source unit and target unit from the conversion table to obtain the respective conversion factors.

# %%
def get_index(conversion_table,from_unit,to_unit):
    from_i=to_i=-1
    for i, item in enumerate(conversion_table):
        if item[1]==from_unit:
            from_i=i
        elif item[1]==to_unit:
            to_i=i
    return from_i, to_i

# %% [markdown]
# The following `convert` function takes the source quantity, source unit, target unit, and pack size, performs unit conversion, and returns the target quantity and unit as a tuple.

# %%
def convert(qty,from_unit,to_unit,pack):
    table=conversion_table(pack)
    from_index, to_index = get_index(table,from_unit,to_unit)
    
    if from_index !=-1 and to_index!=-1 :        
        if from_index>to_index:
            # print('big to small')
            for j in table[to_index:from_index]:
                qty=qty*j[0]
            return_unit=table[to_index][1] 
        elif from_index<to_index:
            # print('small to big')
            for j in table[from_index:to_index]:
                qty=qty/j[0]       
            return_unit=table[to_index][1]
    else:
        return_unit=from_unit            
    return qty,return_unit

# %%
conversion_table(pack = '20 tab * 5 stp * box')
# Out:
# [(20, 'tab'), (5, 'stp'), (1, 'box')]

# %%
get_index (conversion_table('20 tab * 5 stp * box'), from_unit = 'box', to_unit = 'tab')
# Out:
# (2, 0)

# %%
convert(qty = 50, from_unit = 'box', to_unit= 'tab', 
        pack = '20 tab * 5 stp * box')
# Out:
# (5000, 'tab')

# %%
convert(50,'tab', 'box','20 tab * 5 stp * box')
# Out:
# (0.5, 'box')

# %%
conversion_table('20 tab * 5 stp * box')[-1][-1]
# Out:
# 'box'

# %% [markdown]
# #### 2. Determine the Most Common Sales Unit
# To determine the most common sales unit, we will first count the number of invoices, grouping them by each product unit. Then, we will evaluate the most frequently sold unit for each product based on invoice count and store the result in a new column.

# %%
# Group by ProductNo and Unit, and aggregate data
agg_temp_df = pharma_df.groupby(['ProductNo', 'Unit']).agg({
    'ProductName': 'first',
    'InvoiceNo': 'count'
}).reset_index()
agg_temp_df.rename(columns={'InvoiceNo':'InvoiceCount'},inplace=True)
# agg_temp_df

# %%
agg_temp_df.head()
# Out:
#    ProductNo Unit ProductName  InvoiceCount
# 0          1  box         EVE             1
# 1          1  stp         EVE            40
# 2          2  box     Royal D             1
# 3          2  sac     Royal D           119
# 4          3  box     Eposoft             9

# %% [markdown]
# Since `agg_temp_df` holds the invoice count for each product unit, we will now evaluate the most common sales unit, store the results in a new DataFrame, and then merge it with `pharma_df` for further analysis.

# %%
# get the index of the most frequent sales unit 
idx = agg_temp_df.groupby(['ProductNo'])['InvoiceCount'].idxmax()

# %%
frequent_units_df = agg_temp_df.loc[idx, ['ProductNo', 'ProductName', 'Unit']].rename(columns={'Unit': 'FrequentUnit'})

# %%
 # agg_temp_df.loc[idx, ['ProductNo', 'ProductName', 'Unit']].rename(columns={'Unit': 'FrequentUnit'})# frequent_units_df

# %%
pharma_df=pharma_df.merge(frequent_units_df,on=['ProductNo', 'ProductName'])

# %%
pharma_df[pharma_df["Unit"]!=pharma_df["FrequentUnit"]]
# Out:
#        InvoiceNo InvoiceDate  ProductNo  Quantity Unit         ProductName  \
# 7              1  2015-01-01        154         1  box      Neurobion Blue
# 24             1  2015-01-01        229         2  box  Metro-250(Umedica)
# 30             2  2015-01-01        548         5  tab            Vertinil
# 44             3  2015-01-01        213         1  tab      Decolgen Forte
# 62             3  2015-01-01        155         1  box          Vit B Denk
# ...          ...         ...        ...       ...  ...                 ...
# 20616       2959  2015-12-31        111         1  box            Clopilet
# 20617       2959  2015-12-31         84         1  box      Cardivas 3.125
# 20618       2959  2015-12-31        138         1  box         Natrilix SR
# 20628       2957  2015-12-31        927         1  box     25% Glucose Pai
# 20634       2960  2015-12-31        266         2  tab            Stugeron
#
# ...

# %% [markdown]
# As you can see there are 1570 rows to convert.
#
# Finally, we will convert all sales into the most common sales unit.
# #### 3. Apply the Standardized Unit

# %%
def apply_conversion(row):
    if row['Unit'] != row['FrequentUnit']:
        row['Quantity'], row['Unit'] = convert(row['Quantity'], row['Unit'], row['FrequentUnit'], row['PackSize'])
    return row

# %%
pharma_df = pharma_df.apply(apply_conversion, axis=1)

# %%
sum(pharma_df['Unit']!=pharma_df['FrequentUnit'])
# Out:
# 0

# %%
# df.drop(columns='FrequentUnit',inplace=True)

# %%
pharma_df.head(5)
# Out:
#    InvoiceNo InvoiceDate  ProductNo  Quantity Unit               ProductName  \
# 0          1  2015-01-01        338       1.0  bot                   Optimol
# 1          1  2015-01-01         16       1.0  stp                Nutrivita
# 2          1  2015-01-01        354       2.0  pcs  Urgo Plaster Transparent
# 3          1  2015-01-01         74       1.0  stp                  Oramin G
# 4          1  2015-01-01        155       1.0  stp                Vit B Denk
#
#                 PackSize                ChemicalName  Month MonthName  Day  \
# 0                    bot                    Eye Drop      1   January    1
# 1   10 cap * 5 stp * box  Multivitamins and Minerals      1   January    1
# 2          100 pcs * box                     Plaster      1   January    1
# 3    5 cap * 6 stp * box  Multivitamins and Minerals      1   January    1
# 4  10 tab * 10 stp * box                      B1, B6      1   January    1
#
#   FrequentUnit
# 0          bot
# 1          stp
# ...

# %%
# pharma_df.info()

# %% [markdown]
# ## Exploratory Analaysis
# Now that we have cleaned the dataset, it is ready for exploration.

# %%
import matplotlib.pyplot as plt
import matplotlib_inline
import seaborn as sns
sns.set_style('darkgrid')
plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=[9,5]

# %% [markdown]
# ### Daily Sales Activity: Invoice Count / Daily Transaction Volume

# %%
daily_txn_vol_df = pharma_df.groupby("InvoiceDate")["InvoiceNo"].count()

# Plot the trend
plt.figure(figsize=(12,6))
daily_txn_vol_df.plot()
# daily_sales.plot()
plt.xlabel("Date")
plt.ylabel("Number of Invoices")
plt.title("Daily Transaction Volume in 2015")
plt.legend(["Transaction Volume","Sales Volume"])
plt.show()

# %% [markdown]
# ### Monthly Sales Patterns: Daily Transaction Volume

# %%
dtv_df=pharma_df.groupby(["Day","Month","MonthName"]).agg({"Quantity": "sum", "InvoiceNo": "count"}).reset_index()
dtv_df = dtv_df.rename(columns={"InvoiceNo": "InvoiceCount"})

plt.figure(figsize=(12, 6))
sns.lineplot(data=dtv_df, x="Day", y="InvoiceCount", hue="MonthName", marker="o")

plt.xlabel("Day of the Month")
plt.ylabel("Transaction Volume")
plt.title("Monthly Sales Patterns: Daily Transaction Volume")
plt.legend(title="Month",bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### Monthly Trends in Average Daily Transactions

# %%
monthly_txn_df=pharma_df.groupby(["Month","MonthName"]).agg({"Day": "nunique", "InvoiceNo": "count"}).reset_index()
monthly_txn_df = monthly_txn_df.rename(columns={"InvoiceNo": "InvoiceCount"})
monthly_txn_df["AvgDailyTransactions"] = monthly_txn_df["InvoiceCount"]/monthly_txn_df["Day"]
# monthly_txn_df

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_txn_df, x="MonthName", y="AvgDailyTransactions",marker="o")
plt.xticks(rotation=75)
plt.xlabel("Month")
plt.ylabel("Transaction Volume")
plt.title("Average Daily Transactions by Month (2015)")
plt.grid(True)

plt.show()

# %% [markdown]
# ### Monthly Sales Volume

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_txn_df, x="MonthName", y="InvoiceCount",marker="o")
plt.xticks(rotation=75)
plt.xlabel("Month")
plt.ylabel("Transaction Volume")
plt.title("Total Monthly Sales Transactions in 2015")
plt.grid(True)

plt.show()

# %% [markdown]
# ### Comparing Monthly Sales Volume with Daily Averages

# %%
import matplotlib.pyplot as plt

# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot InvoiceCount on primary y-axis
ax1.plot(monthly_txn_df.MonthName, monthly_txn_df.InvoiceCount, label="Total Transactions", linestyle="-", marker="o", color="blue")
ax1.set_xlabel("Month")
ax1.set_ylabel("Transaction Volume", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")
ax1.tick_params(axis="x", labelrotation=75)

# Create secondary y-axis
ax2 = ax1.twinx()
ax2.plot(monthly_txn_df.MonthName, monthly_txn_df.AvgDailyTransactions, label="Avg Daily Transactions", linestyle="--", marker="s", color="red")
ax2.set_ylabel("Transaction Volume", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.tick_params(axis="x", labelrotation=75)

# Improve visualization
plt.title("Comparing Monthly Sales Volume with Daily Averages (2015)")
plt.xticks(rotation=45)
fig.legend(loc="upper right",bbox_to_anchor=(1 ,1))

plt.show()

# %% [markdown]
# This comparison examines how total monthly sales volume relates to average daily transactions within each month. The goal is to understand whether sales are evenly distributed throughout the month or if certain days see spikes in activity.

# %%
# !pip install scikit-learn

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Reshape data for regression
X = monthly_txn_df[["Month"]]  # Independent variable
Y = monthly_txn_df["AvgDailyTransactions"]  # Dependent variable

# Train linear regression model
model = LinearRegression()
model.fit(X, Y)

# Predict future transactions
future_months = pd.DataFrame([[13], [14], [15]], columns=["Month"])
predicted_txn = model.predict(future_months)  # Predict next months
predicted_txn = model.predict(future_months)

# Plot regression line
plt.scatter(monthly_txn_df["Month"], monthly_txn_df["AvgDailyTransactions"], color="blue", label="Actual Data")
plt.plot(monthly_txn_df["Month"], model.predict(X), color="red", label="Regression Line")
plt.xlabel("Month")
plt.ylabel("Avg Daily Transactions")
plt.title("Linear Regression on Monthly Avg Daily Transactions")
plt.legend()
plt.grid(True)
plt.show()

print(f"Predicted values for future months: {predicted_txn}")
# Out:
# Predicted values for future months: [52.74243078 51.23783107 49.73323135]

# %% [markdown]
# ### 2. Product Frequency Analysis
# Find out which products appear most often across invoices.

# %%
product_counts = pharma_df['ProductName'].value_counts().head(10)

# Plot top-selling products
plt.figure(figsize=(10,5))
product_counts.plot(kind='bar')
plt.xlabel("Product Name")
plt.ylabel("Frequency")
plt.title("Top 10 Most Frequent Products")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 1. "Sales Volume Trend: Quantity of Products Sold/ Daily sales volume
# If you want to analyze trends over time, grouping by InvoiceDate can help visualize how product sales fluctuate

# %%
import matplotlib.pyplot as plt

# Group by date to get daily sales count
daily_sales = pharma_df.groupby('InvoiceDate').agg({
    'Quantity':'sum',
    'MonthName':'first'
}).reset_index()

# Plot the trend
# plt.figure(figsize=(12,6))
# daily_sales.plot()
# plt.xlabel("Date")
# plt.ylabel("Total Quantity Sold")
# plt.title("Daily Sales Trend")
# plt.show()


plt.figure(figsize=(12, 6))
sns.lineplot(data=dtv_df, x="Day", y="Quantity", hue="MonthName", marker="o")

plt.xlabel("Day of the Month")
plt.ylabel("Transaction Volume")
plt.title("Monthly Sales Patterns: Daily Transaction Volume")
plt.legend(title="Month",bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### Product Sales Distribution
# We will examine the distribution of sales by product.

# %%
agg_explore_df=pharma_df.groupby(['ProductNo', 'Unit']).agg({
    'ProductName': 'first',
    # 'PackSize':'first',
    # 'Quantity': 'sum',
    'InvoiceNo': 'count'
}).reset_index()
agg_explore_df.rename(columns={'InvoiceNo':'InvoiceCount'},inplace=True)

# %%
# Rearrange the columns order
agg_explore_df=agg_explore_df[['ProductNo','ProductName','Unit','InvoiceCount']]
agg_explore_df.sort_values('InvoiceCount',ascending=False,inplace=True)

# %%
agg_explore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 763 entries, 20 to 29
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductNo     763 non-null    int64
#  1   ProductName   763 non-null    object
#  2   Unit          763 non-null    object
#  3   InvoiceCount  763 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 29.8+ KB

# %%
agg_explore_df.InvoiceCount.describe()
# Out:
# count    763.000000
# mean      27.053735
# std       40.655211
# min        1.000000
# 25%        5.000000
# 50%       12.000000
# 75%       32.500000
# max      360.000000
# Name: InvoiceCount, dtype: float64

# %%
# agg_explore_df

# %%
plt.figure(figsize=(7,2))
sns.boxplot(data=agg_explore_df,x=agg_explore_df.InvoiceCount)

plt.title('Distribution of Product Sales in 2015')
plt.xlabel('Frequency of Sales');

# %% [markdown]
# The outliers in the box plot, titled **'Distribution of Product Sales in 2015'**, indicate products with significantly higher sales. These products outperform others and can be considered high-performing in terms of sales frequency.
#
# - Median (12.0): This represents the middle value of your sales volume, meaning half of the transactions are below 12 and half are above.
# - Q1 (5.0): The first quartile (Q1) indicates that 25% of your sales transactions are at or below 5.
# - Q3 (32.5): The third quartile (Q3) shows that 75% of your sales transactions are at or below 32.5.
# - Lower Whisker (1): The smallest non-outlier sales volume recorded.
# - Upper Whisker (73.75): The highest non-outlier sales volume recorded.
#
# ### Identifying High-Performing Products from Outlier Sales

# %%
import numpy as np
# Calculate key statistics
invoice_counts = agg_explore_df['InvoiceCount']
median = np.median(invoice_counts) 
q1 = np.percentile(invoice_counts, 25) #Q1 is the median of the first half of the data
q3 = np.percentile(invoice_counts, 75)
iqr = q3 - q1
lower_whisker = max(min(invoice_counts), q1 - 1.5 * iqr)
upper_whisker = min(max(invoice_counts), q3 + 1.5 * iqr)

# %%
print('median:',median)
print('q1:',q1)
print('q3:',q3)
print('lower_whisker:',lower_whisker)
print('upper_whisker:',upper_whisker)
# Out:
# median: 12.0
# q1: 5.0
# q3: 32.5
# lower_whisker: 1
# upper_whisker: 73.75

# %%
high_performing_df = agg_explore_df[agg_explore_df['InvoiceCount'] >upper_whisker].reset_index()
# high_performing_products = high_performing_df["ProductName"].unique()

# %%
high_performing_df.shape
# Out:
# (67, 5)

# %% [markdown]
# >**Summary**
# >
# >There are 67 high-performing products with significantly higher sales compared to the rest of the dataset.<br>
# >These products should be well-stocked.

# %% [markdown]
# ### 67 High-Performing Products
# We will visualize the top 67 high-performing products in their most frequent sales units along with their respective sales figures. Please note that the '?' symbols in the product names are a result of font differences and represent non-English words.

# %%
high_performing_df = high_performing_df.sort_values('InvoiceCount', ascending=False)

plt.figure(figsize=(9,34))
ax=sns.barplot(x='InvoiceCount',y='ProductName',data=high_performing_df)

# Add text annotations for each bar
for idx, value in enumerate(high_performing_df['InvoiceCount']):
    ax.text(value, idx, str(value), ha='left', va='center',fontsize=12)
    
labels = [f"{product} ({unit})" for product, unit in zip(high_performing_df.ProductName, high_performing_df.Unit)]

# Customize y-tick labels
plt.yticks(ticks=range(len(high_performing_df)), labels=labels)

plt.xlabel('Number of Invoices')
plt.ylabel('Product Name with Selling Units')
plt.title('67 High-Performing Products in 2015')
plt.annotate('This plot shows the 67 products with the number of sales or transactions in 2015.',
             xy=(0.05, -0.03), xycoords='axes fraction',
             ha='center', fontsize=15)
plt.tight_layout();
# plt.figtext(0.4, -0.1, "This plot shows the 15 products with the highest number of sales or transactions.", wrap=True, horizontalalignment='center', fontsize=12);

# %% [markdown]
# ### Products Sold 5 Times or Fewer
# There are many factors to consider when deciding whether to keep products in the store, such as trends and product types. However, since every product has an expiration date, it is essential to analyze the products with low sales frequency.

# %%
lowest_sales_df=agg_explore_df.groupby('InvoiceCount').agg({'ProductName':'count'}).sort_values(by='InvoiceCount')
plt.bar(x=lowest_sales_df.head(5).index,height='ProductName',data=lowest_sales_df.head(5))

for idx, value in enumerate(lowest_sales_df['ProductName'].head(5)):
    plt.text(lowest_sales_df.index[idx], value, str(value), ha='center', va='bottom', fontsize=12)
    
plt.title('Products Sold 5 Times or Fewer in 2015')
plt.xlabel('Number of Invoices')
plt.ylabel('Number of Products')
plt.figtext(0.5, -0.1, "This graph shows the number of products that were sold 5 times or fewer throughout 2015.", wrap=True, horizontalalignment='center', fontsize=14);

# %% [markdown]
# >**Summary**
# >
# >In 2015, a total of 873 products were sold. Notably, 243 products were sold five times or fewer. These low-performing products should be analyzed further for trends, usage, product types, or chemical composition to decide whether they should remain in the store.<br>
# >To sell these products more quickly, maybe a targeted strategy should be developed, taking their context into account.

# %% [markdown]
# >**Summary**
# >
# >February was the busiest month in 2015, while November was the least busy.
#
# >If the sales frequency is seasonal, inventory preparation using the data can help ensure the availability of high-demand products during peak months and minimize overstock of low-demand products during off-peak months.

# %% [markdown]
# >**Summary**
# >
# >In 2015:<br>
# >* A total of 873 products were sold.
# >* The average number of sales per product was 26.
# >* The product with the least sales was sold only once.
# >* 25% of the products were sold 5 times or fewer.
# >* The median number of sales per product was 12, meaning 50% of the products were sold 12 times or fewer.
# >* 75% of the products were sold 31 times or fewer.
# >* The standard deviation of sales was approximately 38.98. On average, the sales count of a product can deviate by around 39 units from the mean of 26. This means that most product sales likely fall within the range of 26 ± 39.

# %% [markdown]
# With this dataset, you have a structured collection of **invoice details** related to **products, quantities, and chemicals**. Here are a few **analysis ideas** you can explore:
#
# # **Basic Exploratory Data Analysis (EDA)**
# 🔹 **Check missing values** – Identify any gaps in the dataset.
# 🔹 **Summary statistics** – Analyze quantity distributions, product frequencies, and patterns.
# 🔹 **Invoice trend analysis** – Identify seasonal or time-based trends in sales (InvoiceDate).
#
# ### **Sales & Inventory Analysis**
# 🔹 **Top-selling products** – Find the most frequently sold **ProductName**.
# 🔹 **Quantity distribution** – Detect patterns in product quantities sold.
# 🔹 **Stock optimization** – Evaluate whether certain **PackSize** or **Units** affect sales volumes.
#
# ### **Chemical Composition Insights**
# 🔹 **Common chemicals used** – Analyze the frequency of **ChemicalName** in product sales.
# 🔹 **Product-chemical relation** – Identify which products contain specific chemicals more often.
# 🔹 **Unit & chemical correlation** – Check if **certain units or pack sizes** are associated with specific chemicals.
#
# ### **Time-Based Patterns**
# 🔹 **Sales over time** – Group by **InvoiceDate** to find seasonal trends.
# 🔹 **Daily/Monthly analysis** – Breakdown **sales volume per time period** to spot fluctuations.
# 🔹 **Invoice frequency** – Determine peak ordering times.
#
# Would you like **Python code examples** to start with some of these analyses? I can guide you through setting up visualizations or computations! 🚀

# %% [markdown]
# With this dataset, several analytical approaches can provide valuable insights into product sales and distribution patterns. Here are key areas to explore:
#
# ### **1. Sales Distribution Analysis**
#    - **Quantity Distributions**: Identify trends in product sales volume across different units.
#    - **Top-Selling Products**: Rank products by total quantity sold or invoice count.
#
# ### **2. Product Frequency & Demand**
#    - **Invoice Count Trends**: Determine which products appear most frequently across transactions.
#    - **High vs. Low Demand Items**: Compare frequently sold items with those appearing only a few times.
#
# ### **3. Pack Size & Unit Analysis**
#    - **Standardization of Units**: Evaluate variations in unit types (`stp`, `pcs`, `tab`, `bot`) to ensure uniformity.
#    - **Impact of Pack Sizes**: Assess whether larger pack sizes influence sales frequency.
#
# ### **4. Market Trends & Inventory Planning**
#    - **Seasonal or Periodic Demand Shifts**: Identify products with fluctuating sales trends.
#    - **Optimization of Stock Levels**: Use frequency data to forecast demand and avoid overstocking or shortages.
#
# Would you like assistance with visualizing or coding any of these analyses? 🚀

# %% [markdown]
# - Transaction Volume (number of invoices per day)
#     - Shows customer demand and purchasing trends.
#     - Helps identify peak sales periods and slower days.
#     - Can indicate the effectiveness of promotions or seasonal variations.
#
# - Stock Movement (quantity of items sold per day)
#     - Helps in inventory management by tracking how fast products are selling.
#     - Avoids stockouts or overstock situations.
#     - Identifies popular products that might need reordering sooner.
#     By analyzing both, you can optimize pricing, predict demand, and im
